# %%
from bs4 import BeautifulSoup
import requests

header = "date,match,set,gameLength,Player,Team,Enemy_team,position,champion,result,kill,deaths,assists,cs,gold,tower_kill,Inhibitors,Barons,Dragons\n"
header2 = "champion,date,match,set,team,enemy_team,area,order,type\n"
f = open("LPLstats.csv","w")
f2 = open("LPLpickban.csv","w")
sat_list= [1,2,3,4,5]
matchId =[4146,4147,4148,4149,4150,4151,4152,4153]
for matchI in matchId:
    try:
        response2 = requests.get('https://www.thescoreesports.com/lol/matches/'+str(matchI)+'?game=1')
        source2 = response2.text
        soup2 = BeautifulSoup(source2, 'html.parser')
        g_length_1 = str(float(str(soup2.findAll("span",{"class":"GameStatus__time--3Tia0"})[0].get_text()).split(":")[0])*60 +float(str(soup2.findAll("span",{"class":"GameStatus__time--3Tia0"})[0].get_text()).split(":")[1]))
    except:
        continue
    for sat in sat_list:
        try:
            response = requests.get('https://www.thescoreesports.com/lol/matches/'+str(matchI)+'?game='+str(sat))
            source = response.text
            soup = BeautifulSoup(source, 'html.parser')
            tr = soup.findAll("tr")
            date = str(soup.findAll("div",{"class":"MatchMetaData__text--3jhBR"})).split(">")[3].split("<")[0].replace(",","")
            match = str(soup.findAll("div",{"class":"MatchMetaData__text--3jhBR"})).split(">")[17].split("<")[0]
            g_length = str(float(str(soup.findAll("span",{"class":"GameStatus__time--3Tia0"})[0].get_text()).split(":")[0])*60 +float(str(soup.findAll("span",{"class":"GameStatus__time--3Tia0"})[0].get_text()).split(":")[1]))    
            if (sat != 1) and (g_length_1 == g_length):
                continue
            B_result = soup.findAll("span",{"class":"GameStatus__secondaryText--24bAm"})[0].get_text()
            R_result = soup.findAll("span",{"class":"GameStatus__secondaryText--24bAm"})[1].get_text()
            B_gold = str(float(tr[19].get_text().split('Gold')[0].replace("K",""))*1000)
            R_gold = str(float(tr[19].get_text().split('Gold')[1].replace("K",""))*1000)
            b_tk = str(tr[21].get_text().split('Towers')[0])
            r_tk = str(tr[21].get_text().split('Towers')[1])
            b_ih = str(tr[22].get_text().split('Inhibitors')[0])
            r_ih = str(tr[22].get_text().split('Inhibitors')[1])
            b_baron = str(tr[23].get_text().split('Barons')[0])
            r_baron = str(tr[23].get_text().split('Barons')[1])
            td = soup.findAll("td")
            if len(td[109].get_text()) == 1:
                b_dragon= str(td[109].get_text())
            elif len(td[111].get_text()) == 1:
                b_dragon= str(td[111].get_text())
            elif len(td[113].get_text()) == 1:
                b_dragon= str(td[113].get_text())
            if len(td[117].get_text()) == 1:
                r_dragon= str(td[117].get_text())
            elif len(td[115].get_text()) == 1:
                r_dragon= str(td[115].get_text())
            elif len(td[113].get_text()) == 1:
                r_dragon= str(td[113].get_text())
            elif len(td[111].get_text()) == 1:
                r_dragon= str(td[111].get_text())
            bt_kda = td[1].get_text().split("/")
            bt_kill = str(bt_kda[0])
            bt_deaths = str(bt_kda[1])
            bt_assists = str(bt_kda[2])
            bt_cs = str(td[2].get_text())
            bj_kda = td[5].get_text().split("/")
            bj_kill = str(bj_kda[0])
            bj_deaths = str(bj_kda[1])
            bj_assists = str(bj_kda[2])
            bj_cs = str(td[6].get_text())
            bm_kda = td[9].get_text().split("/")
            bm_kill = str(bm_kda[0])
            bm_deaths = str(bm_kda[1])
            bm_assists = str(bm_kda[2])
            bm_cs = str(td[10].get_text())
            ba_kda = td[13].get_text().split("/")
            ba_kill = str(ba_kda[0])
            ba_deaths = str(ba_kda[1])
            ba_assists = str(ba_kda[2])
            ba_cs = str(td[14].get_text())
            bs_kda = td[17].get_text().split("/")
            bs_kill = str(bs_kda[0])
            bs_deaths = str(bs_kda[1])
            bs_assists = str(bs_kda[2])
            bs_cs = str(td[18].get_text())
            rt_kda = td[21].get_text().split("/")
            rt_kill = str(rt_kda[0])
            rt_deaths = str(rt_kda[1])
            rt_assists = str(rt_kda[2])
            rt_cs = str(td[22].get_text())
            rj_kda = td[25].get_text().split("/")
            rj_kill = str(rj_kda[0])
            rj_deaths = str(rj_kda[1])
            rj_assists =str(rj_kda[2])
            rj_cs = str(td[26].get_text())
            rm_kda = td[29].get_text().split("/")
            rm_kill = str(rm_kda[0])
            rm_deaths = str(rm_kda[1])
            rm_assists = str(rm_kda[2])
            rm_cs = str(td[30].get_text())
            ra_kda = td[33].get_text().split("/")
            ra_kill = str(ra_kda[0])
            ra_deaths = str(ra_kda[1])
            ra_assists = str(ra_kda[2])
            ra_cs = str(td[34].get_text())
            rs_kda = td[37].get_text().split("/")
            rs_kill = str(rs_kda[0])
            rs_deaths = str(rs_kda[1])
            rs_assists = str(rs_kda[2])
            rs_cs = str(td[38].get_text())
            champ = soup.findAll("span",{"class":"ImgText__smallSecondaryText--3z6Mr"})
            btc = champ[1].get_text()
            bjc = champ[2].get_text()
            bmc = champ[3].get_text()
            bac = champ[4].get_text()
            bsc = champ[5].get_text()
            rtc = champ[7].get_text()
            rjc = champ[8].get_text()
            rmc = champ[9].get_text()
            rac = champ[10].get_text()
            rsc = champ[11].get_text()
            team = soup.findAll("span",{"class":"ImgText__smallPrimaryText--3UX57"})
            team_blue = team[0].get_text()
            team_red = team[6].get_text()
            team_blue_top = team[1].get_text()+","+team_blue+","+team_red+","+"TOP"+","+btc
            team_blue_jng = team[2].get_text()+","+team_blue+","+team_red+","+"JNG"+","+bjc
            team_blue_mid = team[3].get_text()+","+team_blue+","+team_red+","+"MID"+","+bmc
            team_blue_adc = team[4].get_text()+","+team_blue+","+team_red+","+"ADC"+","+bac
            team_blue_sup = team[5].get_text()+","+team_blue+","+team_red+","+"SUP"+","+bsc
            team_red_top = team[7].get_text()+","+team_red+","+team_blue+","+"TOP"+","+rtc
            team_red_jng = team[8].get_text()+","+team_red+","+team_blue+","+"JNG"+","+rjc
            team_red_mid = team[9].get_text()+","+team_red+","+team_blue+","+"MID"+","+rmc
            Pick1_red = team[26].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"1"+","+"pick"
            BAN1_red = team[27].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"1"+","+"ban"
            BAN2_blue = team[28].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"2"+","+"ban"
            Pick2_blue = team[29].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"2"+","+"pick"
            Pick2_red = team[30].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"2"+","+"pick"
            BAN2_red = team[31].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"2"+","+"ban"
            BAN3_blue = team[32].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"3"+","+"ban"
            Pick3_blue = team[33].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"3"+","+"pick"
            Pick3_red = team[34].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"3"+","+"pick"
            BAN3_red = team[35].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"3"+","+"ban"
            BAN4_blue = team[36].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"4"+","+"ban"
            Pick4_blue = team[37].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"4"+","+"pick"
            Pick4_red = team[38].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"4"+","+"pick"
            BAN4_red = team[39].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"4"+","+"ban"
            BAN5_blue = team[40].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"5"+","+"ban"
            Pick5_blue = team[41].get_text()+","+date+","+match+","+str(sat)+","+team_blue+","+team_red+","+"blue"+","+"5"+","+"pick"
            Pick5_red = team[42].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"5"+","+"pick"
            BAN5_red = team[43].get_text()+","+date+","+match+","+str(sat)+","+team_red+","+team_blue+","+"red"+","+"5"+","+"ban"
            header2 += BAN1_blue+"\n"+Pick1_blue+"\n"+Pick1_red+"\n"+BAN1_red+"\n"+BAN2_blue+"\n"+Pick2_blue+"\n"+Pick2_red+"\n"+BAN2_red+"\n"+BAN3_blue+"\n"+Pick3_blue+"\n"+Pick3_red+"\n"+BAN3_red+"\n"+BAN4_blue+"\n"+Pick4_blue+"\n"+Pick4_red+"\n"+BAN4_red+"\n"+BAN5_blue+"\n"+Pick5_blue+"\n"+Pick5_red+"\n"+BAN5_red+"\n"
        except:
            pass
        
f.write(header)
f.close()
f2.write(header2)
f2.close()
