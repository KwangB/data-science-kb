# %%
import requests
import numpy as pd
import pandas as pd
import time
from datetime import datetime, timezone, timedelta
import datetime

# %%
API_KEY  = 
challenger_league = requests.get("https://kr.api.riotgames.com/lol/league/v3/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key="+API_KEY).json()
master_league = requests.get("https://kr.api.riotgames.com/lol/league/v3/masterleagues/by-queue/RANKED_SOLO_5x5?api_key="+API_KEY).json()
challenger_master_name = []
for i in range(len(challenger_league['entries'])):
    challenger_master_name.append(challenger_league['entries'][i]['playerOrTeamName'])
for i in range(len(master_league['entries'])):
    challenger_master_name.append(master_league['entries'][i]['playerOrTeamName'])

    
accountId = []
summoner_body_name = []
for i in range(len(challenger_master_name)):
    summoner_body = requests.get('https://kr.api.riotgames.com/lol/summoner/v3/summoners/by-name/'+str(challenger_master_name[i])+"?api_key="+API_KEY).json()
    time.sleep(3)
    try:
        accountId.append(summoner_body['accountId'])
        summoner_body_name.append(summoner_body['name'])
        print(summoner_body['accountId'],summoner_body['name'])
    except Exception as ex:
        print(ex,i,challenger_master_name[i])
# Out:
# 210167935 Pireannn
# 204613894 MVP ADD
# 207477934 잘할수있어힘내자
# 3440481 Hide on bush
# 201412938 다표음식은너야
# 5548984 taesang
# 210515107 Mark Time
# 1443543 IM AmazingJ fans
# 2233613 small lady
# 209489592 지는게임내탓
# 202001440 오뚜기3분미트볼
# 202784392 llllllIIIlllIl
# 1972039188344672 lazy son
# 200203708 lookatmy
# 210588840 노력을 또 안했네
# 5775781 구마유시
# 6968626 카페베네설탕도둑
# 209453436 양양아기
# 4930311 Xx fans
# 202657028 I Do han
# 209899057 난 질수없다
# 202937359 KT DEFT
# 1969322938059840 hunjiuwanshile
# 209685625 Jin Air Nova
# 208714024 Levellup
# 209364129 APK Bonnie
# 1972741827473152 ke ai qi
# 1187058 liillili
# 7394257   irmaking
# 206360056 KDM LuBu
# 206966030 Strive XLBcc
# 204840551 혜지기여워
# 206227817 아라가키 유이
# 6965193 뽀오뽀오
# 210166977 2188
# 203870735 GabrielCRO
# 3511615 Gen G CoreJJ
# 206501884 Tarzan fan
# 210168207 무서운원숭이
# 209298941 lulie
# 207309342 See u AG
# 4189406 WithApd
# 202561023 Seroum
# 6871634 aNaT
# 2474930 단군의청춘부재
# 210082154 꼬마 진우
# 207695426 ililiiiillliil
# 208670326 아이러니
# 547086 nekoneko1
# 1539461 Billys
# 210407988 KT Kingen
# 4586738 칼과 창 방패
# 210588930 바위게 내꺼야
# 205940681 BtC Crush
# 208573098 미드프로지망인
# 210168045 Barbarian King
# 200621317 이 차가 식기전에
# 5670561 IruguN
# 210277091 키네카
# 209238536 knight8
# 209871119 wu you wu lu
# 209597990 xuanyi9
# 203769662 JAG Grace
# 1983280090058208 Trud
# 4773767 AMANI
# 206321273 Tank XD
# 206358340 Gen G Ruler
# 206091414 명구리버드
# 207987339 귀여운안지영
# 210168151 학식먹을나이
# 208832237 BtC OnFleek
# 5482776 SKT T1 Bang
# 209157896 칼 창 방패
# 208474131 수 넝
# 1200016 lJlJlJlJ
# 255738 mimimimmm
# 6655208 baby hang
# 209333159 yiwancibeishang
# 206882851 롤마우스
# 204672058 JAG UmTi
# 201236882 SKT T1 ThaI
# 206944308 먹는게즐거워
# 208684744 살기가 힘들다
# 1890305 EndlessSO
# 731011 공연하다
# 210104776 only jiao
# 206247678 플리리
# 207486324 JUGKlNG
# 204152129 Hichael Dackson
# 201232698 DWG BeryL
# 209943564 댕청잇
# 207922335 너와나의연결Gori
# 209070922 댕 체
# 4532453 몽 몽
# 203073673 SKT T1 Le0
# 200362664 riris1
# 208276269 Apk TolanD
# 251448 aoligei
# 210567903 thgink9
# 209829701 MIDKlNG
# 694099 Kizuna치노
# 204167188 츠코파이
# 4061828 백수 썬
# 206452044 귤수호자 만기
# 201412177 BLG Corgi
# 927790 누우운사람
# 1088331 DontRemakeAatr0x
# 210168141 땅만안짚으면되지
# 1309737 Gen G cuvee
# 209682437 띵킹왕
# 203921694 HLE Kuzan
# 1280988 부회장왜그럴까
# 204879466 MeteorOvO
# 4947422 ChoGod
# 210160071 FW MMD1
# 203492844 마산가자
# 207443723 호잇이
# 206154294 Nu99et
# 8027026 SKT T1 Pirean
# 208259196 SD건담캡슐파이
# 6241698 bbq Ccrazy
# 204655734 때린곳또때림
# 210168129 Luka M0dric
# 755064 GimGoon
# 5312679 노틸제발버프좀
# 716483 12qwqewasasdasd
# 209992902 롤오브레전드1234
# 210168031 Deft12345678
# 5241149 StandAchance
# 3494294 살생부만드는사람
# 765726 riris2
# 201306076 Queen Back
# 665129 KT MATA
# 200670975 명jhin이
# 208971849 First start
# 208537812 S0ra
# 1071218 KZ GorillA
# 210581300 Sihyunn
# 207663353 Ritung Rabbit
# 5824372 달마발
# 6023036 Cabelo
# 1972823017066048 20001019z
# 204062750 Gen G Life
# 203542532 남동현
# 5657517 Buterfly
# 210168025 아이거또어우
# 6293499 미곤개 나갈꼬냐
# 210167972 킹존 물만두
# 200578193 프제짱
# 204531622 심심풀이 남신
# 204333883 KZ Peanut
# 209170828 Juan OVO
# 1893908 Afreeca Spirit
# 210504123 always confident
# 1503672 너구리가그린기린
# 5421643 huya zhiqiang
# 209785752 just be patient
# 5093410 Huya CaiqiKate
# 210073241 16살 원딜러
# 6871165 NekoL
# 209274483  hf ghkyu
# 210167940 veryverycold
# 204098604 Lehends
# 3547852 KZ Khan
# 204673167 DDDasher
# 6282837 pvman
# 204158243 Curious PoP
# 6924001 더워뒤짐
# 210167939 한겨레어린이
# 210217049 Z 5 18 15 S
# 210405790 짬뽕짜장탕수육
# 879245 daydayupup
# 1118491 나츠카린
# 7781673 캐리욤
# 203020098 give me courage
# 205248873 MVP Ian
# 201200763 DontRemakeAatrox
# 207901668 세븐틴 하이딘
# 207354982 KZ Cuzz
# 4735341 정상적인 심장
# 204245747 이도류
# 209230380 롤스터단합KT
# 714214 FW Maple
# 204642050 사랑해 나의 라칸
# 209063179 tjudlsawqz
# 210196508 Lakhesis
# 1243363 수입뿌드
# 3972036 TOP Ggoong
# 206107682 KT Ucal
# 207078123 SKT T1 Blossom
# 209173070 MADKlNG
# 1783885 2데스미만
# 200451279 PESK
# 210082459 예리살렘
# 210580312 GCA Done
# 209084978 엽북이
# 4989266 19 15 6 13
# 1551766 퍼그개졸귀
# 1352428 쫄깃한 우동사리
# 203780321 wkfgkrhtlvdj
# 208641446 Igarashi Yuri
# 4255460 A weak man
# 203100039 sim2572
# 2807164 1427538696835724
# 1952335488027776 하늘부터 땅까지
# 2496735 1ang D
# 208036640 n37
# 2728486 BaeMe1
# 2545920 우치하 문강희
# 208685615 zaodianxiaban
# 7530974 Im really sorry
# 1986393140531040 살아있지 못한 자
# 4354535 Jackairay8
# 204668812 gari1
# 208256985 Arrange
# 202716600 위로해드릴게요
# 209952237 스퐈이더맨
# 202947354 PAKA fans
# 203234693 살기시러요
# 7284994 콜르키
# 207013602 WNS Lucifer
# 1951887088028736 Is Who
# 1024691 CrazzyCat
# 209894542 SUP SNOWFLOWER
# 200659835 희미한 너의 미소
# 209588799 롤끊고 인생역전
# 266599 real gankster
# 2604380 OP JG
# 200485531 온실속의감자
# 208571325 buxiangzhangda
# 200939857 정신병 있음 주의
# 1985667 liilliliii
# 6235210 후크노스
# 210477028 SeImoh
# 201697080 Dream or Drink
# 5512755 쭌 쳘
# 2779721 창완이가 최고
# 1668993 나나띵
# 200242402 원딜유저 갓증환
# 200440551 By 불비
# 201386115 1987 Plls
# 210149221 Fox B Road
# 1082228  Eizz1L C
# 3845330 함께 화이팅
# 5236683 다현준의
# 204926209 pour out passion
# 209749515 YMq601658101
# 5199037 Posser
# 210168012 coldnight
# 204026648 전민혁
# 2037243 Keep on keeping
# 5797364 이흥호
# 4388898 온자이족
# 1979972406996064 Cold Hearted
# 210470330 음침한원딜러
# 202422138 FW MooJin
# 5597834 닭 쳐
# 209197502 천천히올라감
# 206158851 부끄부끄
# 210540659 QioC
# 1953101200723776 전기의자 박종우
# 5120515 고분머장
# 2335652 구린내가심하구나
# 4721132 FW SwordArT
# 208180863 ADQ337229251
# 6997034 미진이딱까리
# 203945832 Cryin Fans
# 2859056 격세지감
# 209653748 zaijian qingchun
# 1984150077189696 Tiki taka
# 3706811 뉴트 주니어
# 527276 babymimi
# 210168326 장원한자5급
# 2221562 Cai Xu Kun1
# 208591153 RacheI Gardr1er
# 1513923 곰탱이하루
# 206353515 Morgan5358
# 206808785 To come around
# 1980657763560896 Afreeca 함민기
# 200543394 이기자 할수있다
# 2874609 No way back
# 209416180 AFs HakaM
# 5369680 Fairy hao
# 1976346548939872 Oshino Sh1nobu
# 208562888 Cola Fiona
# 2810810 Dear deer4
# 1410285 지존협곡몬스터
# 7877867 깐 지 닉
# 207496863 귤렐루야
# 209765659 룬 곰
# 206434883 최예나사생팬
# 208351500 Lasttttttttt
# 209610403 Indulge myself
# 5673244 양치하고 자라
# 200585615 California Life
# 4212553 Cw Johnny
# 1886697 보스 서폿
# 209533359 누구도 날 모를껄
# 200196103 Fancity
# 206712533 싫구요
# 209054174 MVP 모티브
# 205721952 7 5
# 207820850 시간의 숲
# 3141212 센센S2
# 202772997 nv shen
# 207130078 dubi ad
# 206298836 wo yao qu daye
# 207609448 Kyanna
# 209640696 Alem gu
# 200260956 PaBo민지
# 210588663 AntiVenom
# 208459546 Like Top
# 200364484 예 율
# 2949434 Wuium
# 2461308 Axiyo
# 209157846 Equality 7 2521
# 207601091 Ten Yan TIA XIA
# 210086222 로족밀타서버니
# 4334995 GHD Dragon
# 203609312 Independenceday1
# 209992146 고려시대 하얀삵
# 203242709 차분하게 하나씩
# 1256292 은율비야
# 238155 다크엠페러김혜성
# 205922254 핏빛 계약
# 202868179 절대짜증내지않기
# 3173012 Eyes
# 1646013 KDM Roach
# 208556423 나에게 기회를
# 202998809 Wudan3lu
# 2679668 Semb fans
# 548226 CloserCloser
# 210099254 1더하기1은 Easy
# 209814299 같이망망망
# 721417 MikuMiku
# 202840283 정치질극혐함
# 3452059 두루미 lv18
# 201475109 Goldguns 하
# 1676336 Ppgod
# 2265734 Rishi
# 207390390 나카노 요츠Ba
# 203517287 Strive girl
# 207074717 내가잘했네
# 208330816 KKKuri
# 7060336 ADzhaodui
# 208023720 Cute MAU O v O b
# 209266514 So I will
# 208660746 DWG Nuguri
# 4271785 내가바로박종우
# 2983104 woquandouya0
# 377501 좋은날
# 3122615 xi ba a
# 200089350 2001 07 28
# 201532538 God Jun z
# 4703224 qi   baby
# 4727868 Run free
# 205501970 LunaTicoo
# 200767254 고구마구고구마
# 4763445 스톡홀름러버
# 209868102 20180817
# 209873589 QiasadingMIDGG
# 4286691 4seidon
# 209736040 제 짱
# 210160070 무자비한 힘
# 239695 Sim Student
# 3454455 cyeol
# 4716375 초원을날뛰는야생
# 210160326 Alex fans
# 4172836 Supreme29
# 2300751 UnicornQaQ
# 6977595 정월 스무이레
# 3153525 그래또
# 2499293 i can fly high
# 3398251 비o수
# 1940682 10월정말약해요
# 1984782817553504 VINXEN
# 210249027 MAD PiPi
# 209607111 Teddy fans
# 201620277 Want be best mid
# 210447799 급체탑
# 202440221 멘탈잡자으쌰으쌰
# 202490343 전일고 김진태
# 204404972 Fox B Pure
# 210373588 황 시한
# 4232216 사랑받기위해태어
# 1952072919551104 운수게임하
# 4049017 Anar alah belore
# 268147 거긴스응감대야
# 3370310 피자 파스타는
# 204544908 Destiny
# 4020503 물음표찍게만들어
# 208744895 KZ Rascal
# 4167583 크림히어로즈팬임
# 4430283 Jin Air Justice
# 3932416 hape girl
# 200471175 핑크퐁동요나라
# 210567660 SKT T1 M1D
# 4513526 Rainbow22
# 4566463 ulRD1
# 206948172 내가마스터라니
# 208057838 Pookyouo
# 200407127 익 뇽
# 2865616 아름다운도시항주
# 209229835 oy oy oy
# 3581979 greed3
# 1038428 Choi inSec
# 205167316 나라카일
# 204517379 KDM X
# 209718342 노력중인레블이
# 3468211 ChenQAQ
# 8036298 LLeave
# 209658935 KZ 1
# 2510493 Ask 섬집아기곰
# 5122925 apraprapr
# 210452072 Liu xiao you
# 203553813 GIorie
# 200222990 LPL noob ad QAQ
# 201463400 헤 돈
# 207120864 귀욤둥이 뽀허니
# 210499610 Do RaoN
# 5724714 이게게임일까
# 1297194 bot only die
# 210248800 Makise Kuris
# 205224935 Twitch Murthhlol
# 1130681 twenty Seven
# 209873592 yizhiyu3
# 209642503 냥 체
# 210406260 새루 유튜브
# 8024711 사람한사람
# 210509782 암컷미니언
# 201336853 000321
# 204428654 성혁님미드가신다
# 203078194 빠빠귤
# 1260046 TS hencool
# 7173097 만 탑
# 1951706307833472 Sunday Monday
# 4818546 양자리 소년
# 4883974 mulda mulda
# 204161823 뽀스타세영
# 209656521 의리 지성 친애
# 4870308 aerosmith v
# 208206029 걱정마 절대안져
# 207332319 jungsanghyun1
# 2681421 호 셍
# 3741293 짜장짬뻥
# 206125812 i want lck duo
# 209324581 뿡 형
# 7795639 술통 볼링
# 208126215 Beriah
# 5802805 죽이다
# 5906669 Gric
# 1635767 이그자일 솔
# 4166529 DouYu CarryKing
# 4356071 douyu1097151
# 1967868964777920 괴안동산바위게
# 204801635 jin can yi
# 208102536 asdojaiosjdo
# 206027314 프리즘스톤
# 1957929235123712 RAGERAGE
# 205937251 스누피808
# 210395272 box666
# 3250382 불가원
# 2525174 Afreeca Kramer
# 202056166 헤 르
# 203573019 skldkrtldkf
# 201323873 BlackGat
# 205943100 블 원
# 203866250 매일 졸려요
# 200822860 SKT T1 BIank
# 208349679 Assam1
# 204196076 사 용 수
# 200828112 찡 후
# 210168310 춘봉박
# 4565138 행성테러범
# 7560576 아쿠아랑께
# 208788037 태풍EYE
# 210133610 pandaTVhuiren
# 880562 의 주
# 204052649 dolcasa
# 203825268 ADG Ace
# 200381865 HanGuo Xiao Daye
# 207532003 사이좋게지내요오
# 206336242 똥 잔나
# 209834687 수분미네랄
# 206682801 가로우식 딜교환
# 1021893 강블린
# 204985890 막걸리 소믈리에
# 209401851 ysdgqxcj
# 4078663 7 21 18
# 1460096 만두 맛있어요
# 207791620 blog note 3
# 210167328 MAD아인슈타인
# 5609003 도인비블루다내꺼
# 7024597 nef9
# 210168149 HLE Sy
# 3957769 Forget it ah
# 207193502 미드가내현
# 200881479 zhixun
# 2720094 정말이뻐해줄게
# 4122399 SKT T1 Untara
# 209402892 중 재
# 208571138 Autumnch
# 794227 HLE LinLan
# 207661604 감귤먹을나이
# 6197385 Heart
# 208352658 아우라백
# 207990525 ToTkr2
# 208059232 shouwa1
# 1338407 help me carry u
# 4736850 배그프로지망
# 206999882 EndorPhinB
# 929620 By myself
# 210087594 Son Of Winnie
# 208721563 조연주 이쁘다
# 1292286 지구야 그럼 목성
# 207931675 Ulquiorra cifer
# 493110 IlIlIllllllll
# 208196584 Camille K
# 1025353 SARUO
# 206280171 율천고 최현우
# 1437517 아테나찡
# 2881442 커피물조절장인
# 5816800 lmdlfmh
# 204819256 세체딩
# 200890830 살려줘요 형님아
# 210168245 HLE 키
# 4778385 shuisongshuisima
# 1980711035768384 갈마동산바위게
# 1992292767412064 나랑롤래TM MID
# 3095385 LeeRoHan
# 204590426 HLE Mightybear
# 1075455 그으뤠이뜨
# 515183 김 궁
# 3913190 신산 언더독
# 207425425 shirushi
# 'accountId' 535 띠용 적 더블킬
# 208434503 처음은누구나초보
# 207173591 RNG Vector
# 209180212 어른마을
# 3084313 aetcal
# 205624948 BtC Do LaoN
# 209825557 샹크스해적왕
# 6786139 겨울지나봄이오듯
# 208287794 20180813 논산go
# 209914720 Patrik Lindberg
# 923899 ertdfklgdfg
# 209254255 문히키
# 210159900 윤소완
# 758274 우르프rider
# 208648862 랜딩아성공하자
# 1302978 갓구 와 잼구612
# 7925635 qjy    QAQ
# 210423808 로밍가는쓰래쉬
# 1568802 계산동블랙쉴드
# 209302113 Blow a kiss
# 1972897308151232 멘탈잡는법몰라요
# 204343674 시게왕
# 201028723 뿌링이
# 202606482 난 질수읍다
# 210446089 Find Team SUP
# 7488288 ktmgs
# 666395 하나의 풍경
# 3142684 초보혁명
# 210001009 한번만 참는다
# 206850039 Khalis
# 201481153 KDM SSol
# 205221940 APK DalKa
# 206325287 더블비 보물섬
# 3777324 용신2
# 1976344291454752 TakeMyHearti
# 208746217 KDM Umaru
# 5990030 Ich liebe dich
# 207908254 11220821
# 1447764 나는여자가좋아요
# 6894195 도전자도전하는자
# 1337260 Luubaby
# 201478650 성보고 권희원
# 210327753 나랑롤래TM JG
# 209217739 허찌킬
# 204119598 데니얼1
# 210499435 Go belive
# 210065458 La Lune tear
# 203826023 모든것이내탓
# 209187556 I do not have to
# 208732190 Tsuruno Junhee
# 209713144 So1o1o
# 205842641 MVP MaHa
# 207528775 팡팡PC방
# 1196206 시마시마 하나코
# 4939473 WeHAVEMOM
# 202911332 MetaMetaMont
# 200129509 촉수아줌마
# 3414924 뭐라고번역하지
# 4268333 때리고또때림
# 2713769 WE 77
# 200398216 CheonGo
# 1587878 앙 88용띠
# 208120798 My name 1s
# 4616199 BeYourse1f
# 209037841 xiaosishen
# 207196668 sibasaki roka
# 210160265 i goto school by
# 206858495 함 물
# 7957489 dafg3121254
# 210466048 VIGlLANTE
# 1982897619677024 응애응애우는사람
# 204162271 KDM Edge
# 202650946 Cott0n
# 2619086 MVP Pilot
# 208863420 Kuri fans
# 5915180 엉덩국 갱승제로
# 200077192 바위게 싸움안해
# 205751852 My Y0Uth
# 208357815 Aopida
# 1198324 mnmnnnmnmnmm
# 209750704 made me believer
# 209176499 HLE Lava
# 205914660 bully bully
# 201283982 우아아  참잘해써
# 209619770 marcozyx
# 204859280 중앙중 원딜러
# 210159890 Tobeornot2be
# 204024521 aceerfa
# 209157881       wan1
# 4189540 Tarzan2
# 208116699 l3est16
# 477199 Mute M1d
# 202021894 handcIap
# 210002502 TenShi
# 206002674 말라말라마츄
# 208276178 헤루갓
# 1972798316473920 ekepX
# 209784607 정글생각하자제발
# 204463363 숨쉴 틈도 없다
# 6369319 칼날부리의 반격
# 210167237 Inuyama Aoi
# 207570975 진에어 테디
# 209848994 swagMEISTER
# 209537469 갱오면계속죽음
# 5205932 외쳐주유소갓라카
# 208144198 이야공
# 208463283 마레리트
# 209873685 mi lao shu
# 208191209 nait9
# 208785601 귀여운 태우
# 204524805 늘 잘할수는 없다
# 209980184 Fairway
# 209056975 KICK TURN
# 200584224 매듭을 고치다
# 1841535 Kur1ko
# 205923395 무서운 뱀 독
# 210479308 빡굴희
# 4814672 Calley
# 4989204 lqslqs
# 1267893 YM601658101
# 208800156 뽀허니
# 209298024 DoRun
# 3209303 원딜전용라이너
# 909429 김국어
# 711143 세양코인
# 208975045 zlp gj
# 206871195 얄랑이
# 204149210 gragas zz
# 203856594 Stars9
# 1958667317431776 shikar7
# 885428 EndIessSO
# 210167917 뚜두두두두뚜
# 741213 i want go club
# 200295174 성 준
# 210547119 yu dao qing ren
# 4056889 yulihong22
# 209618719 Code 희
# 202489165 DWG Nuclear
# 2702936 TopM416
# 3775016 cherry cherry
# 1294369 IlIIIIIllll
# 209192190 생각을 또 안하네
# 206487982 Gen G 몽
# 210160161 Midmain
# 200901221 튀자튀자아
# 'accountId' 680 민 정 뿌
# 690526 Chidanta
# 210160163 토르 팬더
# 2184272 si nian imay
# 209729003 Hanyuuu
# 209893956 Selmoh
# 209791125 ASCZVGFASFAGZSXR
# 4574520 키173cm체중42kg
# 209345433 ESOK
# 208094670 Ssdda
# 6165934 빨간달팽이Lv3
# 209063311 CharmingKiller M
# 6665995 나랑랑이
# 2948352 4월의 요정
# 200890981 작은 방을 채우다
# 201009223 6학년4반장용준
# 200819702 으쭐TENGA
# 210125512 Burdol
# 210217347 JJUN
# 207824339 Knlght
# 208063831 mei you da long
# 7528592 캐 인
# 1489618 프라엘
# 210588664 Leesrael
# 207767502 인성세계최강
# 1558866 Da람G
# 4025085 Steel9
# 2782440 you cant gank me
# 208364809 밤하늘 은
# 207141296 남포동포동포동
# 4315978 돌잔치때도란잡음
# 202079416 섭이는귀여움
# 5435421 iite
# 209334030 Empmuyi
# 207653439 AFR Rainbow
# 4697714 디기디기당디기방
# 7556011 I am noob yanOvO
# 210448349 언제나열심간절
# 6451200 lwandy
# 7859270 IgNar
# 5007058 JJangwane
# 823140 AhriRipper
# 6457821 쉔과나의연결고리
# 210498648 2000 O9 08
# 1990341033913504 M17 Deul
# 2866544 Sol로랭크
# 202103602 WNS WooFe
# 205499309 Baby123
# 4563310 프간로절
# 797737 To start the
# 210444931 Chasy
# 209942048 S2vely
# 1996234539117984 codename777
# 207860462 cherish0120
# 2905522 BtC SoaR
# 1785347 yao OG skr
# 2407177 리그오브레전드ll
# 210360073 세메론
# 2705932 You are a fish
# 201282716 오나전캐안습
# 209630553 Mni
# 207509427 Medic1
# 209896545 hfdidi
# 207845270 pipidan
# 210160155 첸 하오
# 205825868 DaYE
# 202471504 Nearly
# 3264794 히yee찬
# 7170042 Shtu mid
# 1492768 Rainyday9
# 207629924 Deifinu
# 209334774 xiaozhabi
# 209474530 CruuuuuuEl
# 200503142 할아브가주인공
# 1388385 1일30분
# 1714949 GeGeBieMaWole
# 6213021 쌔배래가
# 6439282 2015 09 31
# 202447485 뮤츠으
# 209447800 Upgrade 할거야
# 208099442 GALA1
# 1290264 한남사냥꾼김진호
# 209753118 너 없이도
# 205788814 소미라
# 1816861 유내현
# 202487884 동쁜이 부하0호
# 2100190 helper9
# 205817334 L1sure
# 208116698 1ynaux9
# 208955389 Cuz2
# 210168114 엔타로 스폰지밥
# 209521897 Cord 8
# 204589466 헤이스트TV
# 210405858 shijiemomori
# 207513245 권희원
# 207746956 단합할수있습니다
# 207321900 Love xsping
# 228900 다거짓말
# 209348879 마유즈미
# 5733995 허찌갱
# 4067494 꾸로미
# 305533 LPL Cuvee
# 1972040429243712 jg thx plz
# 209485408 현 솔
# 1472000 Run wind
# 2050829 펭귄z
# 4081560 Baby99
# 2451597 정재현1234
# 210159894 SkrSkrSkrSkr
# 5011292 잉슥2
# 208533470 Afreeca Ruby
# 1497373 Silky
# 3576152 지저동수달
# 204955989 난 찔수없다
# 3453422 모 모
# 2373709 포기하지마 소년
# 210160083 hl4su3a8eji6bp6
# 204710032 2학년6반16번
# 209333258 VCNDJU
# 209497455 메포스노
# 2888036 b1t
# 208030689 밈 누
# 5864306 홍대알바
# 210170457 KT Mia
# 204132693 Keep 90ing
# 209121106 BurgerDragon
# 210166973 freakingcomputer
# 6203629 Cyberbully
# 4585020 아다들너무귀엽다
# 210167931 두두둥두둥웅
# 208917246 6461
# 201067077 클레드는 정글
# 7463140 The Bravely
# 2803913 덕 구
# 206435940 HLE Asper
# 209157499 Wdzzdy
# 3863724 Be proud of me
# 210168327 Im Loyal Dog
# 1414035 떠블유이 Mafa
# 210458662 신이루 후니쨩
# 208575907 작은 셰퍼드
# 'accountId' 821 애플무무
# 6786422 아르니스
# 200782224 swi3e
# 206102224 GimGoon 모쏠황제
# 201053222 포쓰컨드
# 210253977 Foy
# 5788087 정신나가
# 1965237201309152 kheyin
# 1055416 TF Brave
# 2121644 1997 12 14
# 5748929 weidi fight
# 3516152 마마돈워리
# 209283868 TT 보배
# 201903745 m2t0o
# 4823948 jiang you ping
# 207540579 쩜 훈
# 1098202 시계왕
# 203874706 BtC joker
# 5521692 be 9ourself
# 2242949 PutongdeADC
# 207874718 K2ria
# 4876431 Il1l1Il1l1I1llIl
# 3872328 박투신
# 208538232 dont and me say
# 2568516 아름다운산청
# 206491319 DragonSky
# 1011004 taonihouzi
# 2627033 llllllllIIIIlll
# 2793098 힘과마음을모아서
# 202892527 RW xigou
# 4826734 NO 브래인
# 207726863 Excuse
# 733647 ZeroLouise
# 1415812 oho oho
# 6809074 mingjing
# 208562793 Maguafu
# 3402147 giao Martin
# 2995942 YSGYGGS
# 204058482 Pz ZZang
# 209660772 RVS Shark
# 4226889 와리꾸리
# 205199428 So1o
# 209617327 yaeryo
# 1982814430350688 dksarfuvic
# 205641227 땅우놈
# 967214 Lonely Jug
# 1970334890782176 목우목우
# 201817220 화려한 솔로킬
# 209950269 졸린가본데
# 210499527 APK Cover
# 207739464 Martia
# 208177961 19IXU
# 202770866 Frida Kahlo
# 209445665 For My End
# 206521473 변춘수
# 200900269 BtC Dove
# 202931135 Wmir
# 207519248 멍충이3
# 1958609237192128 승현이가나가신다
# 3707534 qhqlwdy
# 4161329 SwhynoobG
# 489053 슈렐리아의사정
# 209433259 R1kka
# 2373850 outplaying
# 210438791 Man of D5
# 206299242 I hate you girl
# 4255382 ExiA Stail
# 207452877 카덴지에
# 204131736 해산물shangdan
# 208970131 Tanwanlanyue
# 201648644 시오도메 미우나
# 1040342 Gen G Ambition
# 7060492 동관짱123
# 6898512 므라기2
# 207769672 AFR ArT
# 210514847 올라가야만한다
# 208471667 아프면살기힘들다
# 203981057 봄에는쭈꾸미
# 205804295 와 이게 죽음
# 204681392 금똥왁왁
# 207912900 풀이없는소나무
# 489826 스마트섹시뷰티
# 210078073 퍼플팀 판빙빙
# 6456409 팡테온
# 210128142 0 웅
# 206772826 모든게내아래
# 210448046 내 뒤에 원딜만
# 209292288 하루 그림자
#             accountId     summoner_name
# 0           210167935          Pireannn
# 1           204613894           MVP ADD
# 2           207477934          잘할수있어힘내자
# 3             3440481      Hide on bush
# 4           201412938           다표음식은너야
# 5             5548984           taesang
# 6           210515107         Mark Time
# 7             1443543  IM AmazingJ fans
# 8             2233613        small lady
# 9           209489592            지는게임내탓
# 10          202001440          오뚜기3분미트볼
# 11          202784392    llllllIIIlllIl
# 12   1972039188344672          lazy son
# 13          200203708          lookatmy
# 14          210588840         노력을 또 안했네
# 15            5775781              구마유시
# 16            6968626          카페베네설탕도둑
# 17          209453436              양양아기
# 18            4930311           Xx fans
# 19          202657028          I Do han
# 20          209899057            난 질수없다
# 21          202937359           KT DEFT
# 22   1969322938059840    hunjiuwanshile
# 23          209685625      Jin Air Nova
# 24          208714024          Levellup
# 25          209364129        APK Bonnie
# 26   1972741827473152          ke ai qi
# 27            1187058          liillili
# 28            7394257          irmaking
# 29          206360056          KDM LuBu
# ..                ...               ...
# 876  1958609237192128          승현이가나가신다
# 877           3707534           qhqlwdy
# 878           4161329         SwhynoobG
# 879            489053           슈렐리아의사정
# 880         209433259             R1kka
# 881           2373850        outplaying
# 882         210438791         Man of D5
# 883         206299242   I hate you girl
# 884           4255382        ExiA Stail
# 885         207452877              카덴지에
# 886         204131736       해산물shangdan
# 887         208970131      Tanwanlanyue
# 888         201648644          시오도메 미우나
# 889           1040342    Gen G Ambition
# 890           7060492            동관짱123
# 891           6898512              므라기2
# 892         207769672           AFR ArT
# 893         210514847           올라가야만한다
# 894         208471667          아프면살기힘들다
# 895         203981057            봄에는쭈꾸미
# 896         205804295           와 이게 죽음
# 897         204681392              금똥왁왁
# 898         207912900           풀이없는소나무
# 899            489826           스마트섹시뷰티
# 900         210078073           퍼플팀 판빙빙
# 901           6456409               팡테온
# 902         210128142               0 웅
# 903         206772826            모든게내아래
# 904         210448046          내 뒤에 원딜만
# 905         209292288            하루 그림자
#
# [906 rows x 2 columns]

# %%
df = pd.DataFrame({'accountId':accountId,'summoner_name': summoner_body_name})
df.to_csv('id_df.csv')
# Out:
#             accountId     summoner_name
# 0           210167935          Pireannn
# 1           204613894           MVP ADD
# 2           207477934          잘할수있어힘내자
# 3             3440481      Hide on bush
# 4           201412938           다표음식은너야
# 5             5548984           taesang
# 6           210515107         Mark Time
# 7             1443543  IM AmazingJ fans
# 8             2233613        small lady
# 9           209489592            지는게임내탓
# 10          202001440          오뚜기3분미트볼
# 11          202784392    llllllIIIlllIl
# 12   1972039188344672          lazy son
# 13          200203708          lookatmy
# 14          210588840         노력을 또 안했네
# 15            5775781              구마유시
# 16            6968626          카페베네설탕도둑
# 17          209453436              양양아기
# 18            4930311           Xx fans
# 19          202657028          I Do han
# 20          209899057            난 질수없다
# 21          202937359           KT DEFT
# 22   1969322938059840    hunjiuwanshile
# 23          209685625      Jin Air Nova
# 24          208714024          Levellup
# 25          209364129        APK Bonnie
# 26   1972741827473152          ke ai qi
# 27            1187058          liillili
# 28            7394257          irmaking
# 29          206360056          KDM LuBu
# ..                ...               ...
# 876  1958609237192128          승현이가나가신다
# 877           3707534           qhqlwdy
# 878           4161329         SwhynoobG
# 879            489053           슈렐리아의사정
# 880         209433259             R1kka
# 881           2373850        outplaying
# 882         210438791         Man of D5
# 883         206299242   I hate you girl
# 884           4255382        ExiA Stail
# 885         207452877              카덴지에
# 886         204131736       해산물shangdan
# 887         208970131      Tanwanlanyue
# 888         201648644          시오도메 미우나
# 889           1040342    Gen G Ambition
# 890           7060492            동관짱123
# 891           6898512              므라기2
# 892         207769672           AFR ArT
# 893         210514847           올라가야만한다
# 894         208471667          아프면살기힘들다
# 895         203981057            봄에는쭈꾸미
# 896         205804295           와 이게 죽음
# 897         204681392              금똥왁왁
# 898         207912900           풀이없는소나무
# 899            489826           스마트섹시뷰티
# 900         210078073           퍼플팀 판빙빙
# 901           6456409               팡테온
# 902         210128142               0 웅
# 903         206772826            모든게내아래
# 904         210448046          내 뒤에 원딜만
# 905         209292288            하루 그림자
#
# [906 rows x 2 columns]

# %%
df = pd.read_csv("id_df.csv")
df['accountId']
then = datetime.datetime.now()
d = then.date()
t = datetime.time(9, 0, 0)
dt = datetime.datetime.combine(d, t)
endTime = int(dt.timestamp()*1e3)
beginTime = int((dt - timedelta(days=1)).timestamp() * 1e3)
gameid = []
for i in range(len(df)):
    match_list = requests.get("https://kr.api.riotgames.com/lol/match/v3/matchlists/by-account/"+str(df['accountId'][i])+"?endTime="+str(endTime)+"&beginTime="+str(beginTime)+"?api_key="+API_KEY).json()
    time.sleep(3)
    for j in range(len(match_list)):
        try:
            gameid.append(match_list[j]["matches"]['gameId'])
        except Exception as ex:
            print(ex,df['accountId'][i])
# Out:
# {'status': {'message': 'Unauthorized', 'status_code': 401}}
